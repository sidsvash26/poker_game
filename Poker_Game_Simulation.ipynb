# %%
from poker_module import *

# %% [markdown]
# ## 1. Game Simulation

# %%
game = PokerGame(chips=500,
                   players = ['a', 
                              'b', 
                              'c'])
# Out:
# Welcome to our Poker Table!
#
# **** Seat positions of the game ****
# a ---> b ---> c ---> a

# %%
game.play(show=['a'])
# Out:
# Small blind: a ($500)
# Big blind: b ($500)
#
# Cards distributed!
# a's private cards : 6♦️  A♣️
#
# ********************
# Pre-flop betting starts
# ********************
# a bets $5.0
# a current bet: 5.0
# a total bet: 5.0
# b bets $10.0
# b current bet: 10.0
# b total bet: 10.0
#
# *************************************************************
#  a ($495.0) --> b ($490.0) --> c ($500) -->
#  $5.0           $10.0          $0
# *************************************************************
#
# Current calling bet: 10.0, Total pot: 15.0
#
# c's TURN
# Choose your action:
# Call (c), Raise: (r), Fold: (f)
# r
# Enter bet/raise amount:
# 100
# c raises to total $100.0
# c current bet: 100.0
# c total bet: 100.0
#
# ***************************************************************
#  a ($495.0) --> b ($490.0) --> c ($400.0) -->
#  $5.0           $10.0          $100.0
# ***************************************************************
#
# Current calling bet: 100.0, Total pot: 115.0
#
# ...
